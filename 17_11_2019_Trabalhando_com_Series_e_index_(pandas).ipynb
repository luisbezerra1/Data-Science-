# %% [markdown]
# <a href="https://colab.research.google.com/github/luisbezerra1/Data-Science-/blob/master/17_11_2019_Trabalhando_com_Series_e_index_(pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv('tags.csv')

# %%
dados.head(50)
# Out:
#     usuarioId  filmeId                    categoria        nota
# 0           2    60756                        funny  1445714994
# 1           2    60756              Highly quotable  1445714996
# 2           2    60756                 will ferrell  1445714992
# 3           2    89774                 Boxing story  1445715207
# 4           2    89774                          MMA  1445715200
# 5           2    89774                    Tom Hardy  1445715205
# 6           2   106782                        drugs  1445715054
# 7           2   106782            Leonardo DiCaprio  1445715051
# 8           2   106782              Martin Scorsese  1445715056
# 9           7    48516                 way too long  1169687325
# 10         18      431                    Al Pacino  1462138765
# 11         18      431                     gangster  1462138749
# 12         18      431                        mafia  1462138755
# 13         18     1221                    Al Pacino  1461699306
# ...

# %%
dados.columns = ('usuarioId','filmeId','categoria','nota')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
# usuarioId    3683 non-null int64
# filmeId      3683 non-null int64
# categoria    3683 non-null object
# nota         3683 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 98.9+ KB

# %%
dados.categoria.unique()
# Out:
# array(['funny', 'Highly quotable', 'will ferrell', ..., 'gun fu',
#        'heroic bloodshed', 'Heroic Bloodshed'], dtype=object)

# %%
sub_dados = dados.categoria

# %%
 sub_dados.drop_duplicates(inplace= True)

# %%
sub_dados.shape[0]
# Out:
# 1589

# %%
sub_dados.index = range(sub_dados.shape[0])

# %%
sub_dados = pd.DataFrame(sub_dados)

# %%
sub_dados
# Out:
#              categoria
# 0                funny
# 1      Highly quotable
# 2         will ferrell
# 3         Boxing story
# 4                  MMA
# ...                ...
# 1584         for katie
# 1585           austere
# 1586            gun fu
# 1587  heroic bloodshed
# 1588  Heroic Bloodshed
#
# [1589 rows x 1 columns]

# %%
sub_dados.index = range(sub_dados.shape[0])

# %%
sub_dados
# Out:
# Id           categoria
# 0                funny
# 1      Highly quotable
# 2         will ferrell
# 3         Boxing story
# 4                  MMA
# ...                ...
# 1584         for katie
# 1585           austere
# 1586            gun fu
# 1587  heroic bloodshed
# 1588  Heroic Bloodshed
#
# [1589 rows x 1 columns]

# %%
sub_dados.columns.name = 'Id'

# %%
sub_dados
# Out:
# Id           categoria
# 0                funny
# 1      Highly quotable
# 2         will ferrell
# 3         Boxing story
# 4                  MMA
# ...                ...
# 1584         for katie
# 1585           austere
# 1586            gun fu
# 1587  heroic bloodshed
# 1588  Heroic Bloodshed
#
# [1589 rows x 1 columns]
